# %% [markdown]
# # Importing Required Libraries

# %%
# importing the required libraries

import pandas as pd
import re
import numpy as np
from word2number import w2n
from datetime import datetime

# %% [markdown]
# # Loading HR Dataset

# %%
# Dataset Loading
hr= pd.read_csv(r"C:\Users\DELL\Desktop\Regonet_project\messy_HR_data.csv")

# %% [markdown]
# # HR Dataset Inspection

# %%
# make a copy of the original dataset
hr_1 = hr.copy()

# %%
hr_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               1000 non-null   object
#  1   Age                841 non-null    object
#  2   Salary             1000 non-null   object
#  3   Gender             1000 non-null   object
#  4   Department         1000 non-null   object
#  5   Position           1000 non-null   object
#  6   Joining Date       1000 non-null   object
#  7   Performance Score  1000 non-null   object
#  8   Email              610 non-null    object
#  9   Phone Number       815 non-null    object
# dtypes: object(10)
# memory usage: 78.3+ KB

# %%
# Dispalying 10 random HR data
hr_1.sample(10, random_state=42)
# Out:
#          Name     Age          Salary  Gender Department   Position  \
# 521      eve       25  SIXTY THOUSAND    Male  Marketing    Manager
# 737   hannah      NaN            NAN     Male         IT      Clerk
# 740    david   thirty            NAN   Female         HR   Director
# 660      eve       35  SIXTY THOUSAND    Male         HR   Director
# 411      ivy       40           70000  Female      Sales      Clerk
# 678    alice       25           55000   Other    Finance      Clerk
# 626    david   thirty           65000  Female         HR    Analyst
# 513    david   thirty  SIXTY THOUSAND    Male      Sales  Assistant
# 859      ivy   thirty  SIXTY THOUSAND    Male    Finance   Director
# 136      ivy       25           50000   Other         IT    Analyst
#
#       Joining Date Performance Score              Email  Phone Number
# 521     2019.12.01                 A                NaN  098-765-4321
# 737     03-25-2019                 C  email@example.com  098-765-4321
# ...

# %% [markdown]
# # Renaming of Columns to conform with Python Naming Conventions

# %%
# Rename the columns to conform with Python variable naming conventions
hr_1 = hr_1.rename(columns={'Joining Date': 'Joining_date', 'Performance Score': 'Performanc_score','Phone Number': 'Phone_number'})
